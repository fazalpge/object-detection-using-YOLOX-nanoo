# %% [markdown]
# <a href="https://colab.research.google.com/github/fazalpge/object-detection-using-YOLOX-nanoo/blob/main/ArUco_marker_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-contrib-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Function to detect ArUco markers
def detect_aruco_markers(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_50)
    aruco_params = cv2.aruco.DetectorParameters()
    corners, ids, rejected = cv2.aruco.detectMarkers(gray, aruco_dict, parameters=aruco_params)

    if ids is not None:
        print(f"Detected {len(ids)} ArUco markers")
    else:
        print("No ArUco markers detected")

    return corners, ids

# Load the image
image_path = '/content/test.jpg'
image = cv2.imread(image_path)
if image is None:
    raise ValueError("Image not loaded properly. Check the file path.")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect ArUco markers
corners, ids = detect_aruco_markers(image)
image_with_aruco = image.copy()

# Draw markers if detected
if ids is not None:
    image_with_aruco = cv2.aruco.drawDetectedMarkers(image_with_aruco, corners, ids)

# Convert to RGB for Matplotlib display
image_with_aruco_rgb = cv2.cvtColor(image_with_aruco, cv2.COLOR_BGR2RGB)

# Save the image with ArUco markers
output_path = '/content/test_with_aruco.jpg'
cv2.imwrite(output_path, image_with_aruco_rgb)

print(f"Saved image with ArUco markers to: {output_path}")
# Out:
# Detected 3 ArUco markers
# Saved image with ArUco markers to: /content/test_with_aruco.jpg

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Placeholder function for object detection using YOLOX
def detect_objects_yolox(image):
    # For demonstration, we'll use dummy data
    boxes = [
        # Format: [x, y, width, height]
        [100, 150, 50, 50],  # Example box for a nut
        [300, 400, 50, 50]   # Example box for another nut
    ]
    class_ids = [0, 0]  # Assume class id 0 corresponds to nuts/bolts

    # Draw bounding boxes on the image
    for (x, y, w, h) in boxes:
        cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)

    return image

# Load the image
image_path = '/content/test.jpg'
image = cv2.imread(image_path)
if image is None:
    raise ValueError("Image not loaded properly. Check the file path.")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect objects with YOLOX and annotate the image
image_with_objects = detect_objects_yolox(image.copy())

# Convert to RGB for Matplotlib display
image_with_objects_rgb = cv2.cvtColor(image_with_objects, cv2.COLOR_BGR2RGB)

# Display the image with objects detected
plt.imshow(image_with_objects_rgb)
plt.title("Object Detection with YOLOX")
plt.show()

# Save the image with objects detected
output_path_objects = '/content/test_with_objects.jpg'
cv2.imwrite(output_path_objects, image_with_objects)

print(f"Saved image with objects detected to: {output_path_objects}")
# Out:
# Saved image with objects detected to: /content/test_with_objects.jpg

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Placeholder function for object detection using YOLOX
def detect_objects_yolox(image):
    # For demonstration, we'll use dummy data
    boxes = [
        # Format: [x, y, width, height]
        [100, 150, 50, 50],  # Example box for a nut
        [300, 400, 50, 50]   # Example box for another nut
    ]
    class_ids = [0, 0]  # Assume class id 0 corresponds to nuts/bolts

    # Draw bounding boxes on the image
    for (x, y, w, h) in boxes:
        cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)

    return image

# Load the image
image_path = '/content/test.jpg'
image = cv2.imread(image_path)
if image is None:
    raise ValueError("Image not loaded properly. Check the file path.")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect objects with YOLOX and annotate the image
image_with_objects = detect_objects_yolox(image.copy())

# Convert to RGB for Matplotlib display
image_with_objects_rgb = cv2.cvtColor(image_with_objects, cv2.COLOR_BGR2RGB)

# Display the image with objects detected
plt.imshow(image_with_objects_rgb)
plt.title("Object Detection with YOLOX")
plt.show()

# Save the image with objects detected
output_path_objects = '/content/test_with_objects.jpg'
cv2.imwrite(output_path_objects, image_with_objects)

print(f"Saved image with objects detected to: {output_path_objects}")
# Out:
# Saved image with objects detected to: /content/test_with_objects.jpg

# %%
# Calculate distances between ArUco markers and detected objects

# Placeholder function for object detection using YOLOX

    # For demonstration, we'll use dummy data
boxes = [
        # Format: [x, y, width, height]
        [100, 150, 50, 50],  # Example box for a nut
        [300, 400, 50, 50]   # Example box for another nut
    ]


def calculate_distances(corners, boxes):
    distances = []
    for marker in corners:
        marker_center = np.mean(marker[0], axis=0)
        for (x, y, w, h) in boxes:
            object_center = np.array([x + w / 2, y + h / 2])
            distance = np.linalg.norm(marker_center - object_center)
            distances.append(distance)
    return distances

distances = calculate_distances(corners, boxes)
print("Distances between ArUco markers and detected objects:", distances)
# Out:
# Distances between ArUco markers and detected objects: [1527.7255357229583, 1289.2615376641002, 1326.6881933973784, 1102.0102370214172, 248.01776650070857, 219.51722597554846]
